# %%
# !pip install geomloss
import os
import time
import torch
import cv2
import numpy as np
# from geomloss import SamplesLoss
import matplotlib.pyplot as plt
from PIL import Image
from IPython.display import display
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.transforms import transforms
from scipy.ndimage import gaussian_filter
from scipy.spatial.distance import cdist
from scipy.io import loadmat

# %%
torch.manual_seed(42)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # Model

# %%
convNext = models.convnext_tiny(weights=models.ConvNeXt_Tiny_Weights.IMAGENET1K_V1)
convNext = convNext.to(device)


class ConvNext_Tiny_Backbone(nn.Module):

    def __init__(self):
        super().__init__()
    
    
    def forward(self, x):   
        x = convNext.features[0](x)
        x = convNext.features[1](x) # 96
        x = convNext.features[2](x)
        x = convNext.features[3](x) # 192
        F1 = x

        x = convNext.features[4](x)
        x = convNext.features[5](x) # 384
        F2 = x

        x = convNext.features[6](x)
        x = convNext.features[7](x) # 768
        F3 = x

        return F1, F2, F3
# Out:
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny-983f1562.pth
# 100%|██████████| 109M/109M [00:00<00:00, 206MB/s]

# %%
class DynamicConvLayer(nn.Module):
    """
    Implements a single dynamic convolution layer (Y(X) from Equation 2)
    with dynamic kernel generation and application, modulated by attention factors.
    It takes an input X and predicts a 1x1 convolution kernel for each sample in the batch.
    """
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = 1 # As per Figure 3 and general dynamic conv usage (1x1 conv)

        # Attention generation for kernel modulation (A(X) from Equation 1)
        # This part generates the A_nk, A_sk, A_ik, A_ok factors.
        # We use a shared MLP output for Ank, Ask, Aik and a separate projector for Aok.
        self.attention_mlp = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)), # AvgPool(X)
            nn.Flatten(),
            nn.Linear(in_channels, in_channels // 8), # FC1
            nn.ReLU()
        )
        
        # Branch for Ank, Ask, Aik (all scale to in_channels dimension)
        self.ank_ask_aik_projector = nn.Sequential(
            nn.Linear(in_channels // 8, 3 * in_channels), # Output for 3 attention dimensions for in_channels
            nn.Sigmoid() # Sigmoid for these factors
        )

        # Branch for Aok (scales to out_channels dimension)
        self.aok_projector = nn.Sequential(
            nn.Linear(in_channels // 8, out_channels), # Project to out_channels for Aok
            nn.Sigmoid() # Sigmoid for Aok
        )

        # 2. Dynamic Kernel Prediction Network
        # This network takes the global pooled features and predicts the 1x1 convolution kernel weights.
        self.kernel_predictor = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(in_channels, in_channels // 8),
            nn.ReLU(),
            nn.Linear(in_channels // 8, self.out_channels * self.in_channels * self.kernel_size * self.kernel_size)
        )

    def forward(self, x):
        N, C, H, W = x.shape # Batch, Channels, Height, Width

        # Generate attention factors (Ank, Ask, Aik, Aok)
        global_feature_for_attention = self.attention_mlp(x)
        
        ank_ask_aik_raw = self.ank_ask_aik_projector(global_feature_for_attention)
        ank_ask_aik = ank_ask_aik_raw.view(N, 3, C) # (N, 3, in_channels)

        Ank = ank_ask_aik[:, 0, :].view(N, C, 1, 1) # (N, in_channels, 1, 1)
        Ask = ank_ask_aik[:, 1, :].view(N, C, 1, 1) # (N, in_channels, 1, 1)
        Aik = ank_ask_aik[:, 2, :].view(N, C, 1, 1) # (N, in_channels, 1, 1)

        Aok = self.aok_projector(global_feature_for_attention).view(N, self.out_channels, 1, 1) # (N, out_channels, 1, 1)


        # Predict raw kernel weights for each sample
        predicted_kernel_raw = self.kernel_predictor(x).view(
            N, self.out_channels, self.in_channels, self.kernel_size, self.kernel_size
        )

        # Modulate the predicted kernels with attention factors
        # Aik (input channels attention): scales along Cin dimension (dim=2 of kernel)
        # Aok (output channels attention): scales along Cout dimension (dim=1 of kernel)
        
        # Expand dimensions for broadcasting:
        # predicted_kernel_raw: (N, Cout, Cin, K, K)
        Aik_expanded = Aik.unsqueeze(1) # (N, 1, Cin, 1, 1) to multiply with (N, Cout, Cin, 1, 1)
        Aok_expanded = Aok.unsqueeze(2) # (N, Cout, 1, 1, 1) to multiply with (N, Cout, Cin, 1, 1)

        modulated_kernel = predicted_kernel_raw * Aik_expanded * Aok_expanded
        
        # Reshape modulated_kernel for F.conv2d with groups=N
        # From (N, Cout, Cin, K, K) to (N*Cout, Cin, K, K)
        kernel_for_conv = modulated_kernel.view(
            N * self.out_channels, self.in_channels, self.kernel_size, self.kernel_size
        )

        # Reshape input X: (N, C, H, W) -> (1, N*C, H, W) for grouped convolution
        x_reshaped = x.reshape(1, N * C, H, W)

        # Perform grouped convolution (groups=N means N independent convolutions, one for each sample)
        conv_output_reshaped = F.conv2d(
            x_reshaped,
            kernel_for_conv,
            stride=1,
            padding=0,
            dilation=1, # Dilation is applied to the kernel weights here, not as a parameter to F.conv2d with a 1x1 kernel unless k>1
            groups=N
        )

        # Reshape back to (N, Cout, H, W)
        conv_output = conv_output_reshaped.view(N, self.out_channels, H, W)
        
        return conv_output


class FocusTransitionModule(nn.Module):
    """
    Implements the Focus Transition Module (FTM) with channel feature weight
    optimization, a simple convolution, and spatial feature weight optimization.
    No dynamic convolution or stacking is used for the convolution part.
    """
    def __init__(self, in_channels, out_channels):
        super().__init__()
        # Channel-wise attention (C(F) in Equation 3)
        self.channel_fc1 = nn.Linear(in_channels, in_channels // 4)
        self.channel_relu = nn.ReLU()
        self.channel_fc2 = nn.Linear(in_channels // 4, in_channels)
        self.channel_sigmoid = nn.Sigmoid()

        # Simple Convolution (replaces dynamic convolution and stacking)
        # This layer transforms the input channels (from F_prime) to out_channels
        self.simple_conv = nn.Sequential(
            DynamicConvLayer(in_channels, in_channels),
            nn.ReLU(inplace=True),
            DynamicConvLayer(in_channels, in_channels),
            nn.ReLU(inplace=True),
            DynamicConvLayer(in_channels, in_channels // 2),
            nn.ReLU(inplace=True),
            DynamicConvLayer(in_channels // 2, out_channels),
            nn.ReLU(inplace=True)
        )

        # Spatial feature weight optimization (S(P) in Equation 5)
        # Input to spatial_conv is always 1 channel after torch.mean(P, dim=1, keepdim=True)
        self.spatial_conv = nn.Conv2d(1, 1, kernel_size=1)
        self.spatial_sigmoid = nn.Sigmoid()

        # Final BatchNorm and ReLU (applied to the output S)
        self.final_bn = nn.BatchNorm2d(out_channels)
        self.final_relu = nn.ReLU()

    def forward(self, x):
        # Input F (x)

        # Channel feature weight optimization C(F)
        avg_pool = F.adaptive_avg_pool2d(x, (1, 1)).squeeze(-1).squeeze(-1) # Global Average Pooling
        channel_attention = self.channel_fc2(self.channel_relu(self.channel_fc1(avg_pool))).unsqueeze(-1).unsqueeze(-1)
        channel_attention = self.channel_sigmoid(channel_attention)
        F_prime = x * channel_attention # Element-wise multiplication

        # Simple Convolution part
        # F_prime has 'in_channels'. Pass through simple conv to get 'out_channels'.
        P = self.simple_conv(F_prime)

        # Spatial feature weight optimization S(P)
        mean_P = torch.mean(P, dim=1, keepdim=True) # Mean value of P across channel dimension (output is 1 channel)
        spatial_attention = self.spatial_sigmoid(self.spatial_conv(mean_P))
        S = P * spatial_attention # Element-wise multiplication

        # Final BatchNorm and ReLU (applied to the output S)
        S = self.final_relu(self.final_bn(S))

        return S

# %%
class MultiScaleFusion(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.transpose2 = nn.ConvTranspose2d(32, 32, kernel_size=2, stride=2)
        self.transpose3 = nn.ConvTranspose2d(64, 64, kernel_size=4, stride=4)

    
    def forward(self, s1, s2, s3):
        h, w = s1.shape[2], s1.shape[3]
        s2 = self.transpose2(s2)
        s3 = self.transpose3(s3)

        S = torch.cat([s1, s2, s3], dim=1)

        return S

# %%
class FFNet(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.backbone = ConvNext_Tiny_Backbone()
        self.focus1 = FocusTransitionModule(192, 16)
        self.focus2 = FocusTransitionModule(384, 32)
        self.focus3 = FocusTransitionModule(768, 64)
        self.fusion = MultiScaleFusion()

        self.conv = nn.Conv2d(112, 1, kernel_size=1)
    

    def forward(self, x):

        f1, f2, f3 = self.backbone(x)

        s1 = self.focus1(f1)
        s2 = self.focus2(f2)
        s3 = self.focus3(f3)

        S = self.fusion(s1, s2, s3)

        density_map = self.conv(S)

        return density_map

# %%
model = FFNet()
model = model.to(device)

# %% [markdown]
# # Dataset Pipeline

# %%
k_nearest = 3
beta = 0.3

def generate_density_map(img, points):

    img_width, img_height = img.size
    d_map_height = img_height // 8
    d_map_width = img_width // 8
    density_map = np.zeros((d_map_height, d_map_width), dtype=np.float32)
    
    if len(points) == 0:
        return density_map

    scaled_points = points / 8
    
    sigmas = []
    if len(scaled_points) > 1:
        distances = cdist(scaled_points, scaled_points)
        
        for i in range(len(scaled_points)):
            sorted_distances = np.sort(distances[i][distances[i] > 1e-6])
            
            if len(sorted_distances) >= k_nearest:
                d_k = sorted_distances[k_nearest - 1]
                sigma_i = beta * d_k
            else:
                sigma_i = beta * np.mean(sorted_distances) if len(sorted_distances) > 0 else 1.0
            sigmas.append(sigma_i)
    else:
        sigmas.append(4.0)
    
    sigmas = np.array(sigmas)
    
    for i, (x, y) in enumerate(scaled_points):
        if int(y) < d_map_height and int(x) < d_map_width:
            point_map = np.zeros_like(density_map)
            point_map[int(y), int(x)] = 1.0
            
            blurred_point_map = gaussian_filter(point_map, sigma=sigmas[i], mode='constant')

            density_map += blurred_point_map
    
    return density_map

# %%
class CustomDataset(Dataset):

    def __init__(self, img_folder_path, point_folder_path):
        self.img_folder_path = img_folder_path
        self.point_folder_path = point_folder_path
        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])


    def __len__(self):
        return(len(os.listdir(self.img_folder_path)))


    def __getitem__(self, index):
        img_path = os.path.join(self.img_folder_path, f"IMG_{index+1}.jpg")
        point_path = os.path.join(self.point_folder_path, f"GT_IMG_{index+1}.mat")

        img = Image.open(img_path).convert("RGB")

        data = loadmat(point_path)
        point = data["image_info"][0][0][0][0][0]

        density_map = generate_density_map(img, points=point.astype(int))
        density_map = torch.from_numpy(density_map).float().unsqueeze(0)

        img = self.transform(img)

        return img, density_map

# %%
train_dataset = CustomDataset("/kaggle/input/crowd-dataset/crowd_wala_dataset/train_data/images", "/kaggle/input/crowd-dataset/crowd_wala_dataset/train_data/ground_truth")
test_dataset = CustomDataset("/kaggle/input/crowd-dataset/crowd_wala_dataset/test_data/images", "/kaggle/input/crowd-dataset/crowd_wala_dataset/test_data/ground_truth")

# %%
batch_size = 4
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4)

# %%
data = loadmat('/kaggle/input/crowd-dataset/crowd_wala_dataset/train_data/ground_truth/GT_IMG_40.mat')
point = data["image_info"][0][0][0][0][0]


img = Image.open("/kaggle/input/crowd-dataset/crowd_wala_dataset/train_data/images/IMG_40.jpg").convert("RGB")

density_map = generate_density_map(img, points=point.astype(int))
density_map_tensor = torch.from_numpy(density_map).float().unsqueeze(0).unsqueeze(0)

upsampled_density_map = torch.nn.functional.interpolate(
    density_map_tensor,
    size=(img.size[1], img.size[0]),
    mode='bilinear',
    align_corners=False).squeeze().cpu().numpy()


true_count = len(point)
estimated_count = np.sum(density_map)

plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title(f'Original Image (True Count: {true_count})')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(upsampled_density_map, cmap='jet')
plt.title(f'Generated Density Map (Est. Count: {estimated_count:.2f})')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Loss Fxn

# %%
class LossFxn(nn.Module):

    def __init__(self, lambda1 = 0.1, lambda2 = 0.01):

        super(LossFxn, self).__init__()

        self.lambda1 = lambda1
        self.lambda2 = lambda2

        ot_params = {'loss': 'sinkhorn', 'p': 2, 'blur': 10, 'debias': True}

        self.ot_loss_fxn = SamplesLoss(**ot_params)
        self.variational_loss = nn.L1Loss()


    def forward(self, y_true, y_pred):

        B, _, H, W = y_pred.shape

        pred_flat = y_pred.view(B, -1) + 1e-8
        true_flat = y_true.view(B, -1) + 1e-8

        pred_dist_norm = pred_flat / pred_flat.sum(dim=1, keepdim=True)
        true_dist_norm = true_flat / true_flat.sum(dim=1, keepdim=True)

        coords_x = torch.arange(W, device=y_pred.device, dtype=y_pred.dtype)
        coords_y = torch.arange(H, device=y_pred.device, dtype=y_pred.dtype)
        
        grid_x, grid_y = torch.meshgrid(coords_x, coords_y, indexing='ij')
        pixel_coords = torch.stack((grid_x.flatten(), grid_y.flatten()), dim=-1)
        pixel_coords_batch = pixel_coords.unsqueeze(0).repeat(B, 1, 1)
        
        ot_loss = self.ot_loss_fxn(pred_dist_norm, pixel_coords_batch, true_dist_norm, pixel_coords_batch)

        count_loss = self.variational_loss(y_true.sum(dim=[1, 2, 3]), y_pred.sum(dim=[1, 2, 3])) / B
        variational_loss = self.variational_loss(y_pred, y_true) / B

        total_loss = count_loss + (self.lambda1 * ot_loss) + (self.lambda2 * variational_loss)

        return total_loss

# %%
learning_rate = 0.0001
epochs = 5

loss_fxn = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # Training Loop

# %%
start = time.time()
model.train()
# losses = []


for i in range(epochs):

    total_epoch_loss = 0
    count = 0

    for batch_image, batch_density_map in train_loader:

        batch_image, batch_density_map = batch_image.to(device), batch_density_map.to(device)

        output = model(batch_image)

        loss = loss_fxn(output, batch_density_map)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        count += 1
        print(f"Batch No.: {count}, Time Elapsed: {(time.time() - start):.1f}, Loss: {loss.item():.5f}")
    
        total_epoch_loss += loss.item()
        losses.append(loss.item())

    avg_epoch_loss = total_epoch_loss / len(train_loader)
    print(f"Epoch: {i+1}, Loss: {avg_epoch_loss}")
# Out:
# Batch No.: 1, Time Elapsed: 1.3, Loss: 0.00487
# Batch No.: 2, Time Elapsed: 3.0, Loss: 0.00601
# Batch No.: 3, Time Elapsed: 4.7, Loss: 0.00567
# Batch No.: 4, Time Elapsed: 6.5, Loss: 0.00521
# Batch No.: 5, Time Elapsed: 8.2, Loss: 0.00385
# Batch No.: 6, Time Elapsed: 9.9, Loss: 0.00818
# Batch No.: 7, Time Elapsed: 11.7, Loss: 0.00263
# Batch No.: 8, Time Elapsed: 13.4, Loss: 0.00284
# Batch No.: 9, Time Elapsed: 15.2, Loss: 0.00542
# Batch No.: 10, Time Elapsed: 16.9, Loss: 0.00256
# Batch No.: 11, Time Elapsed: 18.6, Loss: 0.00460
# Batch No.: 12, Time Elapsed: 20.4, Loss: 0.00916
# Batch No.: 13, Time Elapsed: 22.1, Loss: 0.00909
# Batch No.: 14, Time Elapsed: 23.8, Loss: 0.00832
# Batch No.: 15, Time Elapsed: 25.6, Loss: 0.00486
# Batch No.: 16, Time Elapsed: 27.3, Loss: 0.00465
# Batch No.: 17, Time Elapsed: 29.1, Loss: 0.01321
# Batch No.: 18, Time Elapsed: 30.8, Loss: 0.00539
# Batch No.: 19, Time Elapsed: 32.5, Loss: 0.00832
# Batch No.: 20, Time Elapsed: 34.3, Loss: 0.00491
# Batch No.: 21, Time Elapsed: 36.0, Loss: 0.00350
# Batch No.: 22, Time Elapsed: 37.7, Loss: 0.00333
# Batch No.: 23, Time Elapsed: 39.5, Loss: 0.00152
# Batch No.: 24, Time Elapsed: 41.2, Loss: 0.00779
# Batch No.: 25, Time Elapsed: 43.0, Loss: 0.00498
# Batch No.: 26, Time Elapsed: 44.7, Loss: 0.00705
# Batch No.: 27, Time Elapsed: 46.4, Loss: 0.00579
# Batch No.: 28, Time Elapsed: 48.2, Loss: 0.00620
# Batch No.: 29, Time Elapsed: 49.9, Loss: 0.00537
# Batch No.: 30, Time Elapsed: 51.6, Loss: 0.00721
# Batch No.: 31, Time Elapsed: 53.4, Loss: 0.00402
# Batch No.: 32, Time Elapsed: 55.1, Loss: 0.00388
# Batch No.: 33, Time Elapsed: 56.9, Loss: 0.00482
# Batch No.: 34, Time Elapsed: 58.6, Loss: 0.00441
# Batch No.: 35, Time Elapsed: 60.3, Loss: 0.00365
# Batch No.: 36, Time Elapsed: 62.1, Loss: 0.00993
# Batch No.: 37, Time Elapsed: 63.8, Loss: 0.00486
# Batch No.: 38, Time Elapsed: 65.5, Loss: 0.00487
# Batch No.: 39, Time Elapsed: 67.3, Loss: 0.00560
# Batch No.: 40, Time Elapsed: 69.0, Loss: 0.00562
# Batch No.: 41, Time Elapsed: 70.7, Loss: 0.00351
# Batch No.: 42, Time Elapsed: 72.5, Loss: 0.00731
# Batch No.: 43, Time Elapsed: 74.2, Loss: 0.00854
# Batch No.: 44, Time Elapsed: 76.0, Loss: 0.01200
# Batch No.: 45, Time Elapsed: 77.7, Loss: 0.00570
# Batch No.: 46, Time Elapsed: 79.4, Loss: 0.00529
# Batch No.: 95, Time Elapsed: 164.5, Loss: 0.00759
# Batch No.: 96, Time Elapsed: 166.2, Loss: 0.00221
# Batch No.: 97, Time Elapsed: 168.0, Loss: 0.00725
# Batch No.: 98, Time Elapsed: 169.7, Loss: 0.00279
# Batch No.: 99, Time Elapsed: 171.4, Loss: 0.00346
# Batch No.: 100, Time Elapsed: 173.2, Loss: 0.00660
# Epoch: 1, Loss: 0.005475791707867756
# Batch No.: 1, Time Elapsed: 175.7, Loss: 0.00367
# Batch No.: 2, Time Elapsed: 177.4, Loss: 0.00452
# Batch No.: 3, Time Elapsed: 179.2, Loss: 0.00464
# Batch No.: 4, Time Elapsed: 180.9, Loss: 0.00599
# Batch No.: 5, Time Elapsed: 182.6, Loss: 0.00684
# Batch No.: 6, Time Elapsed: 184.4, Loss: 0.00787
# Batch No.: 7, Time Elapsed: 186.1, Loss: 0.00588
# Batch No.: 8, Time Elapsed: 187.9, Loss: 0.00604
# Batch No.: 9, Time Elapsed: 189.6, Loss: 0.00539
# Batch No.: 10, Time Elapsed: 191.3, Loss: 0.00368
# Batch No.: 11, Time Elapsed: 193.1, Loss: 0.00683
# Batch No.: 12, Time Elapsed: 194.8, Loss: 0.00967
# Batch No.: 13, Time Elapsed: 196.6, Loss: 0.00438
# Batch No.: 14, Time Elapsed: 198.3, Loss: 0.00488
# Batch No.: 15, Time Elapsed: 200.0, Loss: 0.00634
# Batch No.: 16, Time Elapsed: 201.8, Loss: 0.00529
# Batch No.: 17, Time Elapsed: 203.5, Loss: 0.01084
# Batch No.: 18, Time Elapsed: 205.2, Loss: 0.00627
# Batch No.: 19, Time Elapsed: 207.0, Loss: 0.00377
# Batch No.: 20, Time Elapsed: 208.7, Loss: 0.00615
# Batch No.: 21, Time Elapsed: 210.5, Loss: 0.00289
# Batch No.: 22, Time Elapsed: 212.2, Loss: 0.00523
# Batch No.: 23, Time Elapsed: 213.9, Loss: 0.00392
# Batch No.: 24, Time Elapsed: 215.7, Loss: 0.00493
# Batch No.: 25, Time Elapsed: 217.4, Loss: 0.00240
# Batch No.: 26, Time Elapsed: 219.1, Loss: 0.00752
# Batch No.: 27, Time Elapsed: 220.9, Loss: 0.00225
# Batch No.: 28, Time Elapsed: 222.6, Loss: 0.00364
# Batch No.: 29, Time Elapsed: 224.3, Loss: 0.00181
# Batch No.: 30, Time Elapsed: 226.1, Loss: 0.00267
# Batch No.: 31, Time Elapsed: 227.8, Loss: 0.00298
# Batch No.: 32, Time Elapsed: 229.5, Loss: 0.00394
# Batch No.: 33, Time Elapsed: 231.3, Loss: 0.00280
# Batch No.: 34, Time Elapsed: 233.0, Loss: 0.00930
# Batch No.: 35, Time Elapsed: 234.8, Loss: 0.00584
# Batch No.: 36, Time Elapsed: 236.5, Loss: 0.00340
# Batch No.: 37, Time Elapsed: 238.2, Loss: 0.00913
# Batch No.: 38, Time Elapsed: 240.0, Loss: 0.00900
# Batch No.: 39, Time Elapsed: 241.7, Loss: 0.00241
# Batch No.: 40, Time Elapsed: 243.4, Loss: 0.00189
# Batch No.: 21, Time Elapsed: 733.9, Loss: 0.00467
# Batch No.: 22, Time Elapsed: 735.6, Loss: 0.00327
# Batch No.: 23, Time Elapsed: 737.4, Loss: 0.00148
# Batch No.: 24, Time Elapsed: 739.1, Loss: 0.00458
# Batch No.: 25, Time Elapsed: 740.9, Loss: 0.00369
# Batch No.: 26, Time Elapsed: 742.6, Loss: 0.00557
# Batch No.: 27, Time Elapsed: 744.3, Loss: 0.00614
# Batch No.: 28, Time Elapsed: 746.1, Loss: 0.00217
# Batch No.: 29, Time Elapsed: 747.8, Loss: 0.01225
# Batch No.: 30, Time Elapsed: 749.6, Loss: 0.00718
# Batch No.: 31, Time Elapsed: 751.3, Loss: 0.00425
# Batch No.: 32, Time Elapsed: 753.0, Loss: 0.00712
# Batch No.: 33, Time Elapsed: 754.8, Loss: 0.00435
# Batch No.: 34, Time Elapsed: 756.5, Loss: 0.00540
# Batch No.: 35, Time Elapsed: 758.3, Loss: 0.00683
# Batch No.: 36, Time Elapsed: 760.0, Loss: 0.00423
# Batch No.: 37, Time Elapsed: 761.7, Loss: 0.00577
# Batch No.: 38, Time Elapsed: 763.5, Loss: 0.00245
# Batch No.: 39, Time Elapsed: 765.2, Loss: 0.00630
# Batch No.: 40, Time Elapsed: 766.9, Loss: 0.00240
# Batch No.: 41, Time Elapsed: 768.7, Loss: 0.00889
# Batch No.: 42, Time Elapsed: 770.4, Loss: 0.00334
# Batch No.: 43, Time Elapsed: 772.1, Loss: 0.00476
# Batch No.: 44, Time Elapsed: 773.9, Loss: 0.00238
# Batch No.: 45, Time Elapsed: 775.6, Loss: 0.00613
# Batch No.: 46, Time Elapsed: 777.4, Loss: 0.00294
# Batch No.: 47, Time Elapsed: 779.1, Loss: 0.00491
# Batch No.: 48, Time Elapsed: 780.8, Loss: 0.00556
# Batch No.: 49, Time Elapsed: 782.6, Loss: 0.00709
# Batch No.: 50, Time Elapsed: 784.3, Loss: 0.00408
# Batch No.: 51, Time Elapsed: 786.0, Loss: 0.00654
# Batch No.: 52, Time Elapsed: 787.8, Loss: 0.00475
# Batch No.: 53, Time Elapsed: 789.5, Loss: 0.00292
# Batch No.: 54, Time Elapsed: 791.3, Loss: 0.01207
# Batch No.: 55, Time Elapsed: 793.0, Loss: 0.00754
# Batch No.: 56, Time Elapsed: 794.7, Loss: 0.00659
# Batch No.: 57, Time Elapsed: 796.5, Loss: 0.00971
# Batch No.: 58, Time Elapsed: 798.2, Loss: 0.00349
# Batch No.: 59, Time Elapsed: 799.9, Loss: 0.00337
# Batch No.: 60, Time Elapsed: 801.7, Loss: 0.00954
# Batch No.: 61, Time Elapsed: 803.4, Loss: 0.00570
# Batch No.: 62, Time Elapsed: 805.2, Loss: 0.00886
# Batch No.: 63, Time Elapsed: 806.9, Loss: 0.00209
# Batch No.: 64, Time Elapsed: 808.6, Loss: 0.00406
# Batch No.: 65, Time Elapsed: 810.4, Loss: 0.00382
# Batch No.: 66, Time Elapsed: 812.1, Loss: 0.00186
# Batch No.: 67, Time Elapsed: 813.8, Loss: 0.00382
# Batch No.: 68, Time Elapsed: 815.6, Loss: 0.00151
# Batch No.: 69, Time Elapsed: 817.3, Loss: 0.00472
# Batch No.: 70, Time Elapsed: 819.0, Loss: 0.00694
# Batch No.: 71, Time Elapsed: 820.8, Loss: 0.00654
# Batch No.: 72, Time Elapsed: 822.5, Loss: 0.00399
# Batch No.: 73, Time Elapsed: 824.3, Loss: 0.00293
# Batch No.: 74, Time Elapsed: 826.0, Loss: 0.00378
# Batch No.: 75, Time Elapsed: 827.7, Loss: 0.00273
# Batch No.: 76, Time Elapsed: 829.5, Loss: 0.00401
# Batch No.: 77, Time Elapsed: 831.2, Loss: 0.00375
# Batch No.: 78, Time Elapsed: 832.9, Loss: 0.00811
# Batch No.: 79, Time Elapsed: 834.7, Loss: 0.00882
# Batch No.: 80, Time Elapsed: 836.4, Loss: 0.00716
# Batch No.: 81, Time Elapsed: 838.1, Loss: 0.00692
# Batch No.: 82, Time Elapsed: 839.9, Loss: 0.00622
# Batch No.: 83, Time Elapsed: 841.6, Loss: 0.01062
# Batch No.: 84, Time Elapsed: 843.3, Loss: 0.00310
# Batch No.: 85, Time Elapsed: 845.1, Loss: 0.00323
# Batch No.: 86, Time Elapsed: 846.8, Loss: 0.00796
# Batch No.: 87, Time Elapsed: 848.5, Loss: 0.01151
# Batch No.: 88, Time Elapsed: 850.3, Loss: 0.00290
# Batch No.: 89, Time Elapsed: 852.0, Loss: 0.00562
# Batch No.: 90, Time Elapsed: 853.8, Loss: 0.00279
# Batch No.: 91, Time Elapsed: 855.5, Loss: 0.00747
# Batch No.: 92, Time Elapsed: 857.2, Loss: 0.00427
# Batch No.: 93, Time Elapsed: 859.0, Loss: 0.00183
# Batch No.: 94, Time Elapsed: 860.7, Loss: 0.00469
# Batch No.: 95, Time Elapsed: 862.4, Loss: 0.00711
# Batch No.: 96, Time Elapsed: 864.2, Loss: 0.00363
# Batch No.: 97, Time Elapsed: 865.9, Loss: 0.00478
# Batch No.: 98, Time Elapsed: 867.7, Loss: 0.00859
# Batch No.: 99, Time Elapsed: 869.4, Loss: 0.00214
# Batch No.: 100, Time Elapsed: 871.1, Loss: 0.00421
# Epoch: 5, Loss: 0.005266106278868392

# %%
plt.plot(range(1, 1001), losses)
plt.show()

# %%
torch.save(model.state_dict(), 'model_weights_SimplifiedDynamic_FFNet25.pth')

# %%
model = FFNet()
model = model.to(device)
model.load_state_dict(torch.load('/kaggle/input/simplifieddynamic_ffnet25/pytorch/default/1/model_weights_SimplifiedDynamic_FFNet25.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Evaluation

# %%
model.eval()
# Out:
# FFNet(
#   (backbone): ConvNext_Tiny_Backbone()
#   (focus1): FocusTransitionModule(
#     (channel_fc1): Linear(in_features=192, out_features=48, bias=True)
#     (channel_relu): ReLU()
#     (channel_fc2): Linear(in_features=48, out_features=192, bias=True)
#     (channel_sigmoid): Sigmoid()
#     (simple_conv): Sequential(
#       (0): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=192, out_features=24, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=24, out_features=576, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=24, out_features=192, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=192, out_features=24, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=24, out_features=36864, bias=True)
#         )
#       )
#       (1): ReLU(inplace=True)
#       (2): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=192, out_features=24, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=24, out_features=576, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=24, out_features=192, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=192, out_features=24, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=24, out_features=36864, bias=True)
#         )
#       )
#       (3): ReLU(inplace=True)
#       (4): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=192, out_features=24, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=24, out_features=576, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=24, out_features=96, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=192, out_features=24, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=24, out_features=18432, bias=True)
#         )
#       )
#       (5): ReLU(inplace=True)
#       (6): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=96, out_features=12, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=12, out_features=288, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=12, out_features=16, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=96, out_features=12, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=12, out_features=1536, bias=True)
#         )
#       )
#       (7): ReLU(inplace=True)
#     )
#     (spatial_conv): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     (spatial_sigmoid): Sigmoid()
#     (final_bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (final_relu): ReLU()
#   )
#   (focus2): FocusTransitionModule(
#     (channel_fc1): Linear(in_features=384, out_features=96, bias=True)
#     (channel_relu): ReLU()
#     (channel_fc2): Linear(in_features=96, out_features=384, bias=True)
#     (channel_sigmoid): Sigmoid()
#     (simple_conv): Sequential(
#       (0): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=384, out_features=48, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=48, out_features=1152, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=48, out_features=384, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=384, out_features=48, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=48, out_features=147456, bias=True)
#         )
#       )
#       (1): ReLU(inplace=True)
#       (2): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=384, out_features=48, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=48, out_features=1152, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=48, out_features=384, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=384, out_features=48, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=48, out_features=147456, bias=True)
#         )
#       )
#       (3): ReLU(inplace=True)
#       (4): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=384, out_features=48, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=48, out_features=1152, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=48, out_features=192, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=384, out_features=48, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=48, out_features=73728, bias=True)
#         )
#       )
#       (5): ReLU(inplace=True)
#       (6): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=192, out_features=24, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=24, out_features=576, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=24, out_features=32, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=192, out_features=24, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=24, out_features=6144, bias=True)
#         )
#       )
#       (7): ReLU(inplace=True)
#     )
#     (spatial_conv): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     (spatial_sigmoid): Sigmoid()
#     (final_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (final_relu): ReLU()
#   )
#   (focus3): FocusTransitionModule(
#     (channel_fc1): Linear(in_features=768, out_features=192, bias=True)
#     (channel_relu): ReLU()
#     (channel_fc2): Linear(in_features=192, out_features=768, bias=True)
#     (channel_sigmoid): Sigmoid()
#     (simple_conv): Sequential(
#       (0): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=768, out_features=96, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=96, out_features=2304, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=96, out_features=768, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=768, out_features=96, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=96, out_features=589824, bias=True)
#         )
#       )
#       (1): ReLU(inplace=True)
#       (2): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=768, out_features=96, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=96, out_features=2304, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=96, out_features=768, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=768, out_features=96, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=96, out_features=589824, bias=True)
#         )
#       )
#       (3): ReLU(inplace=True)
#       (4): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=768, out_features=96, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=96, out_features=2304, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=96, out_features=384, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=768, out_features=96, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=96, out_features=294912, bias=True)
#         )
#       )
#       (5): ReLU(inplace=True)
#       (6): DynamicConvLayer(
#         (attention_mlp): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=384, out_features=48, bias=True)
#           (3): ReLU()
#         )
#         (ank_ask_aik_projector): Sequential(
#           (0): Linear(in_features=48, out_features=1152, bias=True)
#           (1): Sigmoid()
#         )
#         (aok_projector): Sequential(
#           (0): Linear(in_features=48, out_features=64, bias=True)
#           (1): Sigmoid()
#         )
#         (kernel_predictor): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=(1, 1))
#           (1): Flatten(start_dim=1, end_dim=-1)
#           (2): Linear(in_features=384, out_features=48, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=48, out_features=24576, bias=True)
#         )
#       )
#       (7): ReLU(inplace=True)
#     )
#     (spatial_conv): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     (spatial_sigmoid): Sigmoid()
#     (final_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (final_relu): ReLU()
#   )
#   (fusion): MultiScaleFusion(
#     (transpose2): ConvTranspose2d(32, 32, kernel_size=(2, 2), stride=(2, 2))
#     (transpose3): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(4, 4))
#   )
#   (conv): Conv2d(112, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
eval_metric = nn.L1Loss()

# %%
total_loss = 0
total_mae = 0
total_mse = 0
count = 0

for batch_image, batch_density_map in test_loader:

    batch_image, batch_density_map = batch_image.to(device), batch_density_map.to(device)

    with torch.no_grad():
        output = model(batch_image)

    loss = eval_metric(output, batch_density_map)

    predicted_counts = output.sum(dim=[1, 2, 3])
    true_counts = batch_density_map.sum(dim=[1, 2, 3])

    abs_diff = torch.abs(predicted_counts - true_counts)
    squared_diff = (predicted_counts - true_counts) ** 2
    
    total_mae += torch.sum(abs_diff).item()
    total_mse += torch.sum(squared_diff).item()

    count += 1
    print(f"Batch No.: {count}, Loss: {loss.item()}")

    total_loss += loss.item()

avg_loss = total_loss / (len(test_loader))
avg_mae = total_mae / (len(test_loader) * batch_size)
avg_mse = total_mse / (len(test_loader) * batch_size)

print(f"Avg Loss: {avg_loss}") 
print(f"Avg MAE: {avg_mae}")
print(f"Avg MSE: {avg_mse}")
# Out:
# Batch No.: 1, Loss: 0.0022227303124964237
# Batch No.: 2, Loss: 0.004152926616370678
# Batch No.: 3, Loss: 0.010708319954574108
# Batch No.: 4, Loss: 0.0024984790943562984
# Batch No.: 5, Loss: 0.007695601787418127
# Batch No.: 6, Loss: 0.00949935894459486
# Batch No.: 7, Loss: 0.006601493805646896
# Batch No.: 8, Loss: 0.004190082661807537
# Batch No.: 9, Loss: 0.007511698640882969
# Batch No.: 10, Loss: 0.006998280994594097
# Batch No.: 11, Loss: 0.0021593503188341856
# Batch No.: 12, Loss: 0.004289585165679455
# Batch No.: 13, Loss: 0.006114359945058823
# Batch No.: 14, Loss: 0.00459365826100111
# Batch No.: 15, Loss: 0.002728254534304142
# Batch No.: 16, Loss: 0.00818538572639227
# Batch No.: 17, Loss: 0.006999704986810684
# Batch No.: 18, Loss: 0.004511929117143154
# Batch No.: 19, Loss: 0.014940435998141766
# Batch No.: 20, Loss: 0.014504648745059967
# Batch No.: 21, Loss: 0.0034222579561173916
# Batch No.: 22, Loss: 0.004121077712625265
# Batch No.: 23, Loss: 0.004358348902314901
# Batch No.: 24, Loss: 0.006209089420735836
# Batch No.: 25, Loss: 0.007708965800702572
# Batch No.: 26, Loss: 0.0021828962489962578
# Batch No.: 27, Loss: 0.01188978087157011
# Batch No.: 28, Loss: 0.007731173187494278
# Batch No.: 29, Loss: 0.0066436841152608395
# Batch No.: 30, Loss: 0.004822148941457272
# Batch No.: 31, Loss: 0.003934046253561974
# Batch No.: 32, Loss: 0.00409031892195344
# Batch No.: 33, Loss: 0.005644203629344702
# Batch No.: 34, Loss: 0.004789611324667931
# Batch No.: 35, Loss: 0.006347395479679108
# Batch No.: 36, Loss: 0.003836376126855612
# Batch No.: 37, Loss: 0.007313718553632498
# Batch No.: 38, Loss: 0.010843390598893166
# Batch No.: 39, Loss: 0.01271752268075943
# Batch No.: 40, Loss: 0.005896393209695816
# Batch No.: 41, Loss: 0.0031806547194719315
# Batch No.: 42, Loss: 0.005872390232980251
# Batch No.: 43, Loss: 0.0050222366116940975
# Batch No.: 44, Loss: 0.006304088048636913
# Batch No.: 45, Loss: 0.002736222930252552
# Batch No.: 46, Loss: 0.008010643534362316
# Batch No.: 47, Loss: 0.00516426470130682
# Batch No.: 48, Loss: 0.006381549872457981
# Batch No.: 49, Loss: 0.007296137511730194
# Batch No.: 50, Loss: 0.0025904024951159954
# Batch No.: 51, Loss: 0.00796155259013176
# Batch No.: 52, Loss: 0.003466058522462845
# Batch No.: 53, Loss: 0.004479234106838703
# Batch No.: 54, Loss: 0.007524240296334028
# Batch No.: 55, Loss: 0.009144631214439869
# Batch No.: 56, Loss: 0.0064625926315784454
# Batch No.: 57, Loss: 0.007457595318555832
# Batch No.: 58, Loss: 0.004115601070225239
# Batch No.: 59, Loss: 0.0067327143624424934
# Batch No.: 60, Loss: 0.008279561065137386
# Batch No.: 61, Loss: 0.006101458333432674
# Batch No.: 62, Loss: 0.008004660718142986
# Batch No.: 63, Loss: 0.005483587738126516
# Batch No.: 64, Loss: 0.004893546458333731
# Batch No.: 65, Loss: 0.003529041074216366
# Batch No.: 66, Loss: 0.005759428255259991
# Batch No.: 67, Loss: 0.0021230767015367746
# Batch No.: 68, Loss: 0.007762183900922537
# Batch No.: 69, Loss: 0.00430194940418005
# Batch No.: 70, Loss: 0.004968814551830292
# Batch No.: 71, Loss: 0.00574443768709898
# Batch No.: 72, Loss: 0.0025900378823280334
# Batch No.: 73, Loss: 0.00545878242701292
# Batch No.: 74, Loss: 0.006916943471878767
# Batch No.: 75, Loss: 0.006713440176099539
# Batch No.: 76, Loss: 0.003985665738582611
# Batch No.: 77, Loss: 0.007485579699277878
# Batch No.: 78, Loss: 0.0032524073030799627
# Batch No.: 79, Loss: 0.007120356895029545
# Avg Loss: 0.006025145010126731
# Avg MAE: 30.630713867235787
# Avg MSE: 2303.3680832295477

# %%
total_loss = 0
total_mae = 0
total_mse = 0
count = 0

for batch_image, batch_density_map in train_loader:

    batch_image, batch_density_map = batch_image.to(device), batch_density_map.to(device)

    with torch.no_grad():
        output = model(batch_image)
    
    loss = eval_metric(output, batch_density_map)

    predicted_counts = output.sum(dim=[1, 2, 3])
    true_counts = batch_density_map.sum(dim=[1, 2, 3])

    abs_diff = torch.abs(predicted_counts - true_counts)
    squared_diff = (predicted_counts - true_counts) ** 2
    
    total_mae += torch.sum(abs_diff).item()
    total_mse += torch.sum(squared_diff).item()

    count += 1
    print(f"Batch No.: {count}, Loss: {loss.item()}")

    total_loss += loss.item()

avg_loss = total_loss / (len(train_loader))
avg_mae = total_mae / (len(train_loader) * batch_size)
avg_mse = total_mse / (len(train_loader) * batch_size)

print(f"Avg Loss: {avg_loss}")
print(f"Avg MAE: {avg_mae}")
print(f"Avg MSE: {avg_mse}")
# Out:
# Batch No.: 1, Loss: 0.005965189542621374
# Batch No.: 2, Loss: 0.005240076221525669
# Batch No.: 3, Loss: 0.002657682169228792
# Batch No.: 4, Loss: 0.005610199179500341
# Batch No.: 5, Loss: 0.0040942104533314705
# Batch No.: 6, Loss: 0.0033013136126101017
# Batch No.: 7, Loss: 0.00461349543184042
# Batch No.: 8, Loss: 0.004164194688200951
# Batch No.: 9, Loss: 0.00287948502227664
# Batch No.: 10, Loss: 0.0020047796424478292
# Batch No.: 11, Loss: 0.0038955172058194876
# Batch No.: 12, Loss: 0.0029076552018523216
# Batch No.: 13, Loss: 0.005784965120255947
# Batch No.: 14, Loss: 0.008767496794462204
# Batch No.: 15, Loss: 0.0008597589330747724
# Batch No.: 16, Loss: 0.004961303900927305
# Batch No.: 17, Loss: 0.005172055214643478
# Batch No.: 18, Loss: 0.007412445731461048
# Batch No.: 19, Loss: 0.00908602774143219
# Batch No.: 20, Loss: 0.01025232020765543
# Batch No.: 21, Loss: 0.006212834268808365
# Batch No.: 22, Loss: 0.01124132052063942
# Batch No.: 23, Loss: 0.006859487853944302
# Batch No.: 24, Loss: 0.005469786934554577
# Batch No.: 25, Loss: 0.0033523328602313995
# Batch No.: 26, Loss: 0.007390297017991543
# Batch No.: 27, Loss: 0.010900180786848068
# Batch No.: 28, Loss: 0.002728857798501849
# Batch No.: 29, Loss: 0.004515928216278553
# Batch No.: 30, Loss: 0.008487941697239876
# Batch No.: 31, Loss: 0.00343897077254951
# Batch No.: 32, Loss: 0.0037636826746165752
# Batch No.: 33, Loss: 0.006729430519044399
# Batch No.: 34, Loss: 0.005184776149690151
# Batch No.: 35, Loss: 0.006179213523864746
# Batch No.: 36, Loss: 0.002416476607322693
# Batch No.: 37, Loss: 0.004531486891210079
# Batch No.: 38, Loss: 0.002494083484634757
# Batch No.: 39, Loss: 0.008360750041902065
# Batch No.: 40, Loss: 0.007735075429081917
# Batch No.: 41, Loss: 0.011122843250632286
# Batch No.: 42, Loss: 0.006723123602569103
# Batch No.: 43, Loss: 0.0014960754197090864
# Batch No.: 44, Loss: 0.004405106417834759
# Batch No.: 45, Loss: 0.003316191490739584
# Batch No.: 46, Loss: 0.004636954516172409
# Batch No.: 47, Loss: 0.0043013738468289375
# Batch No.: 48, Loss: 0.003958031535148621
# Batch No.: 49, Loss: 0.004073101095855236
# Batch No.: 50, Loss: 0.004923633765429258
# Batch No.: 51, Loss: 0.0031877588480710983
# Batch No.: 52, Loss: 0.003693586215376854
# Batch No.: 53, Loss: 0.005935888737440109
# Batch No.: 54, Loss: 0.002309294417500496
# Batch No.: 55, Loss: 0.006769868545234203
# Batch No.: 56, Loss: 0.006250482983887196
# Batch No.: 57, Loss: 0.007944190874695778
# Batch No.: 58, Loss: 0.003001976292580366
# Batch No.: 59, Loss: 0.008304949849843979
# Batch No.: 60, Loss: 0.0071203745901584625
# Batch No.: 61, Loss: 0.007148046046495438
# Batch No.: 62, Loss: 0.007914245128631592
# Batch No.: 63, Loss: 0.0038790141697973013
# Batch No.: 64, Loss: 0.00705217570066452
# Batch No.: 65, Loss: 0.0027505340985953808
# Batch No.: 66, Loss: 0.00707775866612792
# Batch No.: 67, Loss: 0.004752514883875847
# Batch No.: 68, Loss: 0.0038115745410323143
# Batch No.: 69, Loss: 0.005369178485125303
# Batch No.: 70, Loss: 0.011439352296292782
# Batch No.: 71, Loss: 0.011839427053928375
# Batch No.: 72, Loss: 0.006911264266818762
# Batch No.: 73, Loss: 0.005940746050328016
# Batch No.: 74, Loss: 0.010429760441184044
# Batch No.: 75, Loss: 0.005864080041646957
# Batch No.: 76, Loss: 0.0036032693460583687
# Batch No.: 77, Loss: 0.006547920405864716
# Batch No.: 78, Loss: 0.0018053579842671752
# Batch No.: 79, Loss: 0.005066690966486931
# Batch No.: 80, Loss: 0.0027733263559639454
# Batch No.: 81, Loss: 0.003941723145544529
# Batch No.: 82, Loss: 0.004834963008761406
# Batch No.: 83, Loss: 0.004300104454159737
# Batch No.: 84, Loss: 0.005379901733249426
# Batch No.: 85, Loss: 0.0077418796718120575
# Batch No.: 86, Loss: 0.0038295905105769634
# Batch No.: 87, Loss: 0.004719719756394625
# Batch No.: 88, Loss: 0.0044545698910951614
# Batch No.: 89, Loss: 0.0034751666244119406
# Batch No.: 90, Loss: 0.006449807435274124
# Batch No.: 91, Loss: 0.004468001425266266
# Batch No.: 92, Loss: 0.0023405763786286116
# Batch No.: 93, Loss: 0.005322909913957119
# Batch No.: 94, Loss: 0.003031006781384349
# Batch No.: 95, Loss: 0.004177083261311054
# Batch No.: 96, Loss: 0.0016296691028401256
# Batch No.: 97, Loss: 0.007174407131969929
# Batch No.: 98, Loss: 0.0028579863719642162
# Batch No.: 99, Loss: 0.007482658140361309
# Batch No.: 100, Loss: 0.0021888702176511288
# Avg Loss: 0.005328747242456302
# Avg MAE: 30.711089453697205
# Avg MSE: 2354.7445029067994

# %%
from scipy.ndimage import maximum_filter


data = loadmat('/kaggle/input/crowd-dataset/crowd_wala_dataset/test_data/ground_truth/GT_IMG_2.mat')
point = data["image_info"][0][0][0][0][0]


img = Image.open("/kaggle/input/crowd-dataset/crowd_wala_dataset/test_data/images/IMG_2.jpg").convert("RGB")
width, height = img.size

density_map = generate_density_map(img, points=point.astype(int))
density_map_tensor = torch.from_numpy(density_map).float().unsqueeze(0).unsqueeze(0)
upsampled_density_map = torch.nn.functional.interpolate(
    density_map_tensor,
    size=(img.size[1], img.size[0]),
    mode='bilinear',
    align_corners=False).squeeze().cpu().numpy()


transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
with torch.no_grad():
    img_ = transform(img)
    img_ = img_.to(device)
    predicted_density_map = model(img_.unsqueeze(0))
    upsampled_predicted_density_map = torch.nn.functional.interpolate(
        predicted_density_map,
        size=(height, width),
        mode='bilinear',
        align_corners=False).squeeze().cpu().numpy()


true_count = len(point)
estimated_count = np.sum(density_map)
predicted_count = predicted_density_map.sum().item()


max_pred_density_value = np.max(upsampled_predicted_density_map)
max_pred_density_coords_flat = np.argmax(upsampled_predicted_density_map)
max_pred_density_peak_row, max_pred_density_peak_col = np.unravel_index(
    max_pred_density_coords_flat, upsampled_predicted_density_map.shape
)


plt.figure(figsize=(20, 6))

plt.subplot(1, 4, 1)
plt.imshow(img)
plt.title(f'Original Image (True Count: {true_count})')
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(upsampled_density_map, cmap='jet')
plt.title(f'Generated Density Map (Est. Count: {estimated_count:.2f})')
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(upsampled_predicted_density_map, cmap='jet')
plt.title(f'Predicted Density Map (Pred. Count: {predicted_count:.2f})')
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(img)
plt.scatter(max_pred_density_peak_col, max_pred_density_peak_row, 
            color='red', s=1000, marker='.', edgecolors='black', linewidth=5, 
            label=f'Pred Max Peak (Val: {max_pred_density_value:.2f})')
plt.title(f'Original Image with Predicted Highest Density Point')
plt.axis('off')
plt.legend()

plt.tight_layout()
plt.show()
